# %% [markdown]
# # Project 8 -- Arnav Surve

# %% [markdown]
# **TA Help:** N/A
#
# **Collaboration:** N/A

# %% [markdown]
# ## Question 1

# %%
import pandas as pd
users = pd.read_parquet("/anvil/projects/tdm/data/yelp/data/parquet/users.parquet")
reviews = pd.read_parquet("/anvil/projects/tdm/data/yelp/data/parquet/reviews.parquet")
pd.set_option('display.max_columns', None)

# %%
users.head()
# Out:
#                   user_id      name  review_count        yelping_since  \
# 0  ntlvfPzc8eglqvk92iDIAw    Rafael           553  2007-07-06 03:27:11
# 1  FOBRPlBHa3WPHFB5qYDlVg  Michelle           564  2008-04-28 01:29:25
# 2  zZUnPeh2hEp0WydbAZEOOg    Martin            60  2008-08-28 23:40:05
# 3  QaELAmRcDc5TfJEylaaP8g      John           206  2008-09-20 00:08:14
# 4  xvu8G900tezTzbbfqmTKvA      Anne           485  2008-08-09 00:30:27
#
#    useful  funny  cool                                         elite  \
# 0     628    225   227
# 1     790    316   400                 2008,2009,2010,2011,2012,2013
# 2     151    125   103                                          2010
# 3     233    160    84                                          2009
# 4    1265    400   512  2009,2010,2011,2012,2014,2015,2016,2017,2018
#
#                                              friends  fans  average_stars  \
# 0  oeMvJh94PiGQnx_6GlndPQ, wm1z1PaJKvHgSDRKfwhfDg...    14           3.57
# 1  ly7EnE8leJmyqyePVYFlug, pRlR63iDytsnnniPb3AOug...    27           3.84
# 2  Uwlk0txjQBPw_JhHsQnyeg, Ybxr1tSCkv3lYA0I1qmnPQ...     5           3.44
# 3  iog3Nyg1i4jeumiTVG_BSA, M92xWY2Vr9w0xoH8bPplfQ...     6           3.08
# 4  3W3ZMSthojCUirKEqAwGNw, eTIbuu23j9tOgmIa9POyLQ...    78           4.37
#
#    compliment_hot  compliment_more  compliment_profile  compliment_cute  \
# 0               3                2                   1                0
# 1              36                4                   5                2
# 2               9                6                   0                1
# 3               2                1                   0                0
# 4               8                9                   2                1
#
#    compliment_list  compliment_note  compliment_plain  compliment_cool  \
# 0                1               11                15               22
# 1                1               33                37               63
# 2                0                3                 7               17
# 3                0                7                14                7
# 4                1               22                28               31
#
#    compliment_funny  compliment_writer  compliment_photos
# 0                22                 10                  0
# 1                63                 21                  5
# 2                17                  4                  1
# 3                 7                  2                  0
# 4                31                 19                 31

# %%
reviews.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  xQY8N_XvtGbearJ5X4QryQ  OwjRMXRC0KyPrIlcjaXeFQ  -MhfebM0QIsKt87iDN-FNw
# 1  UmFMZ8PyXZTY2QcwzsfQYA  nIJD_7ZXHq-FX8byPMOkMQ  lbrU8StCq3yDfr-QMnGrmQ
# 2  LG2ZaYiOgpr2DK_90pYjNw  V34qejxNsCbcgD8C0HVk-Q  HQl28KMwrEKHqhFrrDqVNQ
# 3  i6g_oA9Yf9Y31qt0wibXpw  ofKDkJKXSKZXu5xJNGiiBQ  5JxlZaqCnk1MnbgRirs40Q
# 4  6TdNDKywdbjoTkizeMce8A  UgMW8bLE0QMJDCkQ1Ax5Mg  IS4cv902ykd8wj1TR0N3-A
#
#    stars  useful  funny  cool  \
# 0      2       5      0     0
# 1      1       1      1     0
# 2      5       1      0     0
# 3      1       0      0     0
# 4      4       0      0     0
#
#                                                 text                date
# 0  As someone who has worked with many museums, I... 2015-04-15 05:21:16
# 1  I am actually horrified this place is still in... 2013-12-07 03:16:52
# 2  I love Deagan's. I do. I really do. The atmosp... 2015-12-05 03:18:11
# 3  Dismal, lukewarm, defrosted-tasting "TexMex" g... 2011-05-27 05:30:52
# 4  Oh happy day, finally have a Canes near my cas... 2017-01-14 21:56:57

# %%
mylistoffriends = users[users['user_id'] == 'ntlvfPzc8eglqvk92iDIAw']['friends'].iloc[0].split(", ")

# %%
users[users['user_id'].isin(mylistoffriends)].shape
# Out:
# (13, 22)

# %%
mylistoffriends = users[users['user_id'] == 'FOBRPlBHa3WPHFB5qYDlVg']['friends'].iloc[0].split(", ")

# %%
users[users['user_id'].isin(mylistoffriends)].shape
# Out:
# (78, 22)

# %%
mylistoffriends = users[users['user_id'] == 'zZUnPeh2hEp0WydbAZEOOg']['friends'].iloc[0].split(", ")

# %%
users[users['user_id'].isin(mylistoffriends)].shape
# Out:
# (13, 22)

# %%
def get_friends_data(myuserid: str) -> pd.DataFrame:
    # accepts myuserid and returns pd dataframe contaaining user info for each friend of myuserid
    mylistoffriends = users[users['user_id'] == myuserid]['friends'].iloc[0].split(", ")
    return users[users['user_id'].isin(mylistoffriends)]

# %%
get_friends_data('ntlvfPzc8eglqvk92iDIAw')
# Out:
#                         user_id    name  review_count        yelping_since  \
# 4439     CIZGlEw-Bp0rmkP8M6yQ9Q   Scott          2464  2009-09-04 16:36:46
# 4709     deL6e_z9xqZTIODKqnvRXQ   Nikki           531  2011-04-09 03:51:06
# 8640     IkRib6Xs91PPW7pon7VVig   Jenny           127  2008-08-18 12:35:48
# 12984    mJLRvqLOKhqEdkgt9iEaCQ   Irene           133  2009-09-13 15:04:14
# 88713    UKf66_MPz0zHCP70mF6p1g   Brian           792  2014-02-11 04:29:20
# 216316   EQpFHqGT9Tk6YSwORTtwpg    Alex           743  2012-07-08 20:24:04
# 220450   s8gK7sdVzJcYKcPv2dkZXw     Dan           359  2011-12-17 00:50:43
# 398185   pZeGZGzX-ROT_D5lam5uNg   Adina           124  2009-02-21 01:42:45
# 605073   QFjqxXn3acDC7hckFGUKMg  Jaeman             8  2012-05-10 06:00:51
# 609430   UZSDGTDpycDzrlfUlyw2dQ     Guo             6  2012-03-19 12:11:09
# 1198181  hbcjX4_D4KIfonNnwrH-cg    Ryan           205  2007-04-27 06:06:42
# 1219310  p59u2EC_qcmCmLeX1jCi5Q  Liliya            93  2014-10-02 23:05:05
# 1388009  5mG2ENw2PylIWElqHSMGqg    John           692  2011-05-08 20:42:44
#
#          useful  funny   cool                                         elite  \
# 4439      15622   8569  11780  2010,2011,2012,2013,2014,2015,2016,2017,2018
# 4709       4647   2399   3229       2011,2012,2013,2014,2015,2016,2017,2018
# 8640        604    318    510
# 12984       366     48    237                           2012,2013,2014,2015
# 88713      2237    912   1914                                2016,2017,2018
# 216316     1094    382    727
# 220450     1592    864   1340                           2015,2016,2017,2018
# 398185      313     75    152                                          2011
# 605073       62     25     49
# 609430        2      0      1
# 1198181     758    463    494
# 1219310     222     87     74
# 1388009    4838   2343   3848            2012,2013,2014,2015,2016,2017,2018
#
#                                                    friends  fans  \
# 4439     WPw0LDmsT5HLc5itX8YLVA, q01khtt3I3bWBvHGxwA6vA...   645
# 4709     scu1qTGz6xsVKgW_-0Gmjw, -gQm-IoK2_BMEMx9OgtQnw...   198
# 8640     MGqAAAAv1bCLybzsAZo6cA, H4s9fuXZ6xCSY6cdR3U6xg...    33
# 12984    avHtVxFKeMI-fVhllE8qwg, D-ZyQ4iT1XRFkcOAWXnxCQ...    18
# 88713    5k44TvM0xWm5iGHlSbuY1Q, quUS0rvD_dE2ECK89jVKaA...    56
# 216316   0G-QF457q_0Z_jKqh6xWiA, CWWXjR2KtVC2o0hBVZ3LVQ...    55
# 220450   ylPi8o14Lavus9DXTm61tQ, eKUGKQRE-Ywi5dY55_zChg...    73
# 398185   ds7B6mRJgP18mOvLISZpSg, 4Rlp6oFr5qd40mTHfNOQ0Q...    18
# 605073   fE6gSbmm5N_pPF5ZbY6h0w, DwIetk5y9m6AypCjPux6RQ...    82
# 609430   nMUmwVr31ySPRZb7lvTZEA, 1XZY9l7p_T4iW0h0gAJmNg...     1
# 1198181  T8AcaLi2dcDTCvPtFgxKxg, H_1yBqXDoVi9ZNbrqlob5Q...    31
# 1219310  DSfqGrB-pxOBF499Zp1lzg, magt280KUVj9bLiXjQZd-g...    18
# 1388009  kSiwBkptGzjeGJh5wG6q3w, Rto4xWr5gXA2IbrfyAn-Xg...   206
#
#          average_stars  compliment_hot  compliment_more  compliment_profile  \
# 4439              3.72             460               52                  52
# 4709              3.50             659               33                  30
# 8640              3.96              75                9                   9
# 12984             3.99              16                8                   2
# 88713             3.70              36                6                   6
# 216316            3.96              18               11                   3
# 220450            3.89             160                8                   4
# 398185            4.08              12                6                   3
# 605073            4.46              30               14                  11
# 609430            4.89               0                0                   0
# 1198181           4.18              19                3                   1
# 1219310           3.05               3                0                   0
# 1388009           3.79             178               27                  17
#
#          compliment_cute  compliment_list  compliment_note  compliment_plain  \
# 4439                   6               40              461              1002
# 4709                  29                9              203               532
# 8640                  20                5               28                55
# 12984                  7                0               17                17
# 88713                  1                3               47                39
# 216316                 3                0               35                57
# 220450                 0                0               73               354
# 398185                 0                0               10                14
# 605073                 0                0               51               353
# 609430                 0                0                0                 0
# 1198181                2                1               22                60
# 1219310                1                0                3                14
# 1388009               18                5               97               570
#
#          compliment_cool  compliment_funny  compliment_writer  \
# 4439                 896               896                458
# 4709                 511               511                192
# 8640                  95                95                 20
# 12984                 35                35                 20
# 88713                149               149                 43
# 216316                47                47                 14
# 220450               272               272                 59
# 398185                19                19                  7
# 605073               134               134                 23
# 609430                 0                 0                  0
# 1198181               46                46                  5
# 1219310                1                 1                  2
# 1388009              527               527                288
#
#          compliment_photos
# 4439                   150
# 4709                   449
# 8640                    10
# 12984                    8
# 88713                  147
# 216316                   9
# 220450                 272
# 398185                   1
# 605073                   7
# 609430                   0
# 1198181                 23
# 1219310                  1
# 1388009                204

# %%
get_friends_data('FOBRPlBHa3WPHFB5qYDlVg')
# Out:
#                         user_id     name  review_count        yelping_since  \
# 35       dIIKEfOgo0KqUfGQvGikPg     Gabi          2061  2007-08-10 19:01:51
# 226      QJI9OSEn6ujRCtrX06vs1w        J          1981  2007-03-19 18:15:32
# 244      UVxY0iyPaqY7s4BSFtt-xA  Wanugee          1950  2007-06-11 03:54:14
# 343      UmXzwFM2OkZHWJ5cJZlqkg   Thomas           538  2007-05-03 03:40:29
# 498      UG4EKu13JRwzRix6ESINdg   Edward          1138  2009-06-05 16:32:55
# ...                         ...      ...           ...                  ...
# 1579951  yjUtVmn9QCgu-p0aG0EhgQ    Shawn            38  2011-11-10 21:08:47
# 1619229  Ccoapq4XJg78LdyhU4lZng     Moku            41  2013-01-25 07:27:40
# 1771839  GGWjA8v479feCo6OPTLQOg       CT           127  2008-11-03 18:44:20
# 1772081  9_ME--bvyZStdz6iwGzMCw     Tony           116  2007-08-24 18:55:32
# 1786958  H58nmfUs-Nz_wwcYfWN3Dg        P            18  2012-06-13 17:37:43
#
#          useful  funny   cool  \
# 35        20024   9684  16904
# 226       14195   6553  10059
# 244       21009  13313  17241
# 343        8705  10778   8511
# 498        2618   1149   1537
# ...         ...    ...    ...
# 1579951      23      9     14
# 1619229       9      5      2
# 1771839    6941   8328   6986
# 1772081     568    456    508
# 1786958      60     26     63
#
#                                                      elite  \
# 35       2007,2008,2009,2010,2011,2012,2013,2014,2015,2...
# 226                                                   2010
# 244                               2008,2009,2010,2011,2012
# 343                                              2007,2008
# 498                2011,2012,2013,2014,2015,2016,2017,2018
# ...                                                    ...
# 1579951
# 1619229
# 1771839                                          2009,2010
# 1772081                                               2008
# 1786958
#
#                                                    friends  fans  \
# 35       6Y-l3x4LpUNhTBVMTFmTmA, HYNhRw_-8g660mpnwY2VJA...   971
# 226      _Oz_-_BrfcxqR3Uvwd4-BA, VNkM5LH4eKrmVP8mBiUcdg...   308
# 244      XddLMXnUKNdz1T7hHnvwoQ, F9oeQCUdV2cZO5AhdJKsMw...   511
# 343      1auiKWhC66RPVHdQI2SvdA, eZZGotIUjs__TCvp-Wr5YA...   263
# 498      cZzrlxbs_JaYW1hraGfzaw, 7nGjCzVTDKTnbRv3gA-TMg...    57
# ...                                                    ...   ...
# 1579951  Gxu8g6IDK5pbM_9ReT8Hmg, 9FknGjHHH6dzxggVw9QabQ...     4
# 1619229  UYcmGbelzRa0Q6JqzLoguw, eJZwGZ2Vpijzy3n57-Szvw...     2
# 1771839  DLb5v7WoHQc7MR9hxMESIw, POkxasEhHHvHpmgzPBVIVA...   254
# 1772081  _oiXgIbfclY9c3HyjlIUWw, kmE8w5Y785eZmodsx0V6Ag...    14
# 1786958  gUz-2ba_IYfLh_BWTeMowQ, to5QXyxyI84QCR9JJMXrSw...     6
#
#          average_stars  compliment_hot  compliment_more  compliment_profile  \
# 35                4.07            1587               85                  94
# 226               3.61            1282               98                 156
# 244               3.52            3122              247                 216
# 343               3.66             891               68                  31
# 498               3.62              53               13                   2
# ...                ...             ...              ...                 ...
# 1579951           3.72               0                0                   0
# 1619229           3.18               0                0                   0
# 1771839           4.22            2597              270                 116
# 1772081           4.38              56               11                   4
# 1786958           3.60               2                0                   0
#
#          compliment_cute  compliment_list  compliment_note  compliment_plain  \
# 35                   231               96             1171              3272
# 226                   52               68              786              3673
# 244                  251              127             1331              4136
# 343                   98               45              388              1527
# 498                    2                0               57               117
# ...                  ...              ...              ...               ...
# 1579951                0                0                0                 5
# 1619229                0                0                0                 0
# 1771839              215               46             1128              3352
# 1772081                8                2               34                89
# 1786958                0                0                2                10
#
#          compliment_cool  compliment_funny  compliment_writer  \
# 35                  2169              2169                463
# 226                 2088              2088                562
# 244                 4491              4491               1382
# 343                  778               778                180
# 498                   97                97                 19
# ...                  ...               ...                ...
# 1579951                1                 1                  2
# 1619229                2                 2                  0
# 1771839             3477              3477                714
# 1772081              103               103                 11
# 1786958               15                15                  0
#
#          compliment_photos
# 35                     281
# 226                   1504
# 244                    970
# 343                     48
# 498                      4
# ...                    ...
# 1579951                  1
# 1619229                  0
# 1771839                132
# 1772081                  5
# 1786958                  0
#
# [78 rows x 22 columns]

# %%
get_friends_data('zZUnPeh2hEp0WydbAZEOOg')
# Out:
#                         user_id                      name  review_count  \
# 1025     nkN_do3fJ9xekchVC-v68A                    Jeremy          1363
# 2338     x9g-i1DsB-VjSDGVOdRonA                 Elizabeth            73
# 5887     jU9aSDYxNIXb7j7oESxe2w                     Carly            45
# 10359    -AaBjWJYiQxXkCMDlXfPGw                       Tim           717
# 16780    7cmEMOLyD4GS1XbjctJpoQ                       Guy           222
# 198068   KavG2RBt77vRLqG1_6RBvQ                   Carolyn           671
# 199105   KKlGiwN0g8p89eQkMyhvKg                       Rob           663
# 202957   93ZaU3GfaXSr-RjabsaQ2Q                      Gary            61
# 394613   Cvvu2V_FO3FjxIHpartSMg                       Sam           854
# 395923   DNmeLov3wXNxlxjN5feBoQ                    Jerome           643
# 999401   h-sDf97w0r_JDOVUtzLT8Q  Jhuliet ''Walks To Eat''            40
# 1187808  1HC_-rWi1oaB-N3BjqGKoQ                     Tisha            23
# 1576416  ZnxSdo0cVyH4HEdDlwlv-w                   Melinda            45
# 1576720  ekGZOsYf7lAOpQlD_j8t5Q                         J           180
#
#                yelping_since  useful  funny   cool  \
# 1025     2004-10-12 08:46:43   18256   9971  14912
# 2338     2008-08-11 16:02:15     489    411    404
# 5887     2009-08-08 03:03:14     327    159    230
# 10359    2009-01-21 01:27:49    2841   1344   1461
# 16780    2008-10-07 01:41:37     279     80     91
# 198068   2008-10-13 06:31:46    3482   3020   3013
# 199105   2009-02-09 03:00:44    2214   1201   1443
# 202957   2008-01-11 02:01:17     254     76    102
# 394613   2008-05-28 03:34:15   11416   7096   9227
# 395923   2008-06-02 00:59:39    5894   4506   4574
# 999401   2012-11-18 04:20:14     231    175    214
# 1187808  2008-06-11 00:02:14      68     22     27
# 1576416  2009-07-19 03:14:44     258    139    200
# 1576720  2008-12-13 04:59:58     373    206    263
#
#                                                      elite  \
# 1025     2006,2007,2008,2009,2010,2011,2012,2013,2014,2...
# 2338                                                  2009
# 5887
# 10359                                       2009,2010,2011
# 16780                                                 2009
# 198068                            2009,2010,2011,2012,2013
# 199105                                           2009,2010
# 202957
# 394613   2009,2010,2011,2012,2013,2014,2015,2016,2017,2018
# 395923   2009,2010,2011,2012,2013,2014,2015,2016,2017,2018
# 999401
# 1187808
# 1576416
# 1576720                           2009,2010,2011,2012,2013
#
#                                                    friends  fans  \
# 1025     MK1H5OCUyPayL_nfSjMm6A, 3ejotiHbd3qB8M1ZSr6iuw...  2046
# 2338     GZMDgKtwuP7FFtut24IZZg, _txhy3UvyGffFh8FLO2_qw...    16
# 5887     Ez7OB58ciPCfLVqofd6YQg, N9pTk3lOJN3Dh5d1f9rTFQ...     8
# 10359    ekGZOsYf7lAOpQlD_j8t5Q, KKlGiwN0g8p89eQkMyhvKg...    37
# 16780    y0ZU1w6YY4W-KtMeRXSYLg, mIJoy1L3Yp8cLMR06ESccg...     4
# 198068   7ON-pEbPXzZ7dpMebSRzrg, rk3deA0rPWqjH5ylNK2y4g...    74
# 199105   DgrkaxfNoMP1nGGrDcpkOw, 0KjqHIouprEuBr_8A9BJ_Q...    32
# 202957   BjvJYccHn0RY0n07vj9OmQ, G9Vb6yQ047TC3O_-GG4WZA...    16
# 394613   VDTvXteVDWfWtKyXCnFY3w, ZUQzjdRrvVpBrSzVnCncJg...   207
# 395923   pI44KNBxtO_BeYM8KVx9BQ, Fm9zntNS_6n3j_yL73sbdw...   198
# 999401   u9a4Wpte8_KRQXpbNpuY9Q, cEj_Vm8n7O4YnUzo6zaNzA...    35
# 1187808  uAhlm1Y3Abxa1zADLUBNVQ, UcBtlqFtR7ovbbcjbhL1TA...     1
# 1576416  jU9aSDYxNIXb7j7oESxe2w, cWVsDzn7L7dwL9c5tubwaQ...    16
# 1576720  g_pA-44jrHfPaupWHInifA, _3uiqQZg5WHAQfaECVH6aw...    13
#
#          average_stars  compliment_hot  compliment_more  compliment_profile  \
# 1025              3.70            1403              176                 149
# 2338              3.85              55                7                   3
# 5887              3.93              57                6                   7
# 10359             3.64             112               14                   7
# 16780             3.89               2                0                   2
# 198068            3.12             518               48                  38
# 199105            4.05              62                9                   5
# 202957            3.90              15                3                   0
# 394613            3.62            1066              124                 123
# 395923            4.03             497               42                  35
# 999401            4.16              97                8                  13
# 1187808           4.32               2                1                   0
# 1576416           4.22              44                7                   8
# 1576720           3.71              33                1                   1
#
#          compliment_cute  compliment_list  compliment_note  compliment_plain  \
# 1025                 249               45              857              1233
# 2338                   3                5               21               168
# 5887                   4                2               15                56
# 10359                  2                0              133               163
# 16780                  0                0               11                 3
# 198068               115                5              259               335
# 199105                 6                3               51               109
# 202957                 5                1               17                11
# 394613                31               42              485              2585
# 395923                36                8              234               779
# 999401                12                1               62                72
# 1187808                1                0                0                 0
# 1576416                4                1               17                64
# 1576720                3                0               23                14
#
#          compliment_cool  compliment_funny  compliment_writer  \
# 1025                2056              2056                460
# 2338                  67                67                 17
# 5887                  86                86                 17
# 10359                400               400                 67
# 16780                  7                 7                  2
# 198068               570               570                121
# 199105               149               149                 22
# 202957                12                12                  2
# 394613              1971              1971                682
# 395923               681               681                289
# 999401               126               126                 26
# 1187808                1                 1                  0
# 1576416               77                77                  5
# 1576720               38                38                  6
#
#          compliment_photos
# 1025                   562
# 2338                     5
# 5887                     0
# 10359                   10
# 16780                    3
# 198068                  32
# 199105                  23
# 202957                   4
# 394613                  53
# 395923                 121
# 999401                  71
# 1187808                  1
# 1576416                  7
# 1576720                  1

# %% [markdown]
# ## Question 2

# %%
reviews[reviews['business_id'] == '-MhfebM0QIsKt87iDN-FNw']['stars'].mean()
# Out:
# 3.295698924731183

# %%
reviews[reviews['business_id'] == '5JxlZaqCnk1MnbgRirs40Q']['stars'].mean()
# Out:
# 3.406779661016949

# %%
reviews[reviews['business_id'] == 'faPVqws-x-5k2CQKDNtHxw']['stars'].mean()
# Out:
# 4.496284394456718

# %%
def calculate_avg_business_stars(mybusinessid: str) -> float:
    # accepts mybusinessid and returns a float of the average number of stars
    return reviews[reviews['business_id'] == mybusinessid]['stars'].mean()

# %%
calculate_avg_business_stars('-MhfebM0QIsKt87iDN-FNw')
# Out:
# 3.295698924731183

# %%
calculate_avg_business_stars('5JxlZaqCnk1MnbgRirs40Q')
# Out:
# 3.406779661016949

# %%
calculate_avg_business_stars('faPVqws-x-5k2CQKDNtHxw')
# Out:
# 4.496284394456718

# %% [markdown]
# ## Question 3

# %%
import matplotlib.pyplot as plt

# %%
mydf = reviews[reviews['business_id'] == "-MhfebM0QIsKt87iDN-FNw"]

# %%
plt.plot(mydf.groupby(mydf['date'].dt.year)['stars'].mean())

# %%
mydf = reviews[reviews['business_id'] == "5JxlZaqCnk1MnbgRirs40Q"]

# %%
plt.plot(mydf.groupby(mydf['date'].dt.year)['stars'].mean())

# %%
mydf = reviews[reviews['business_id'] == "faPVqws-x-5k2CQKDNtHxw"]

# %%
plt.plot(mydf.groupby(mydf['date'].dt.year)['stars'].mean())

# %%
def visualize_stars_over_time(mybusinessid: str) -> None:
    # Accepts mybusinessid string and generates a line plot showing the average number of stars in each year (for which the business has reviews)
    mydf = reviews[reviews['business_id'] == mybusinessid]
    plt.plot(mydf.groupby(mydf['date'].dt.year)['stars'].mean())
    return None

# %%
visualize_stars_over_time("-MhfebM0QIsKt87iDN-FNw")

# %%
visualize_stars_over_time("5JxlZaqCnk1MnbgRirs40Q")

# %%
visualize_stars_over_time("faPVqws-x-5k2CQKDNtHxw")

# %% [markdown]
# ## Question 4

# %%
def visualize_stars_over_time(mybusinessid: str, granularity: str = "years") -> None:
    # Accepts mybusinessid string and generates a line plot showing the average number of stars in each year (for which the business has reviews)
    mydf = reviews[reviews['business_id'] == mybusinessid]
    
    if granularity == "months":
        plt.plot(mydf.groupby([mydf['date'].dt.year,mydf['date'].dt.month])['stars'].mean().reset_index(drop=True))
    else:
        plt.plot(mydf.groupby(mydf['date'].dt.year)['stars'].mean())
    return None

# %%
visualize_stars_over_time("-MhfebM0QIsKt87iDN-FNw")

# %%
visualize_stars_over_time("-MhfebM0QIsKt87iDN-FNw", "years")

# %%
visualize_stars_over_time("-MhfebM0QIsKt87iDN-FNw", "months")

# %%
visualize_stars_over_time("5JxlZaqCnk1MnbgRirs40Q")

# %%
visualize_stars_over_time("5JxlZaqCnk1MnbgRirs40Q", "years")

# %%
visualize_stars_over_time("5JxlZaqCnk1MnbgRirs40Q", "months")

# %%
visualize_stars_over_time("faPVqws-x-5k2CQKDNtHxw")

# %%
visualize_stars_over_time("faPVqws-x-5k2CQKDNtHxw", "years")

# %%
visualize_stars_over_time("faPVqws-x-5k2CQKDNtHxw", "months")

# %% [markdown]
# ## Question 5

# %%
def visualize_stars_over_time(*allofmybusinessids) -> None:
    # Accepts mybusinessid string and generates a line plot showing the average number of stars in each year (for which the business has reviews)
    
    for mybusinessid in allofmybusinessids:
        mydf = reviews[reviews['business_id'] == mybusinessid]
        plt.plot(mydf.groupby(mydf['date'].dt.year)['stars'].mean())
    plt.show()
    return None

# %%
visualize_stars_over_time("-MhfebM0QIsKt87iDN-FNw", "5JxlZaqCnk1MnbgRirs40Q", "faPVqws-x-5k2CQKDNtHxw")

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
